# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
#series ........
score=pd.Series([55,66,77,45,76,87,45])
print("score=",score)
score[2]
# Out:
# score= 0    55
# 1    66
# 2    77
# 3    45
# 4    76
# 5    87
# 6    45
# dtype: int64
# np.int64(77)

# %%
score=pd.Series([55,66,77,45,76,87,45]
                ,index=["qaim","saara","summiya","ali","khan","jan","liaba"])


#print(score)
#score["summiya"]
score=[score > 80]
print(score)
# Out:
# [qaim       False
# saara      False
# summiya    False
# ali        False
# khan       False
# jan         True
# liaba      False
# dtype: bool]

# %%
#data frames.................
data={"name":["qaim","ali","summiya"],
      "age":[19,20,21],
      "score":[78,88,98],
      "study_hours":[3,4,5]
      }
students=pd.DataFrame(data)
students
# Out:
#       name  age  score  study_hours
# 0     qaim   19     78            3
# 1      ali   20     88            4
# 2  summiya   21     98            5

# %%
students['name']
# Out:
# 0       qaim
# 1        ali
# 2    summiya
# Name: name, dtype: object
